# %%
N = int(input())
count = 0
new_N = N
while (0 <= N <= 99):
    count += 1

    A = new_N // 10
    B = new_N % 10

    if A == 0:
        C = B * 10 + (A + B)
    else:
        C = B * 10 + (A + B) % 10

    if C == N:
        print(count)
        break

    new_N = C
# Out:
# 1
# 60
