# %%
H, M = map(int, input().split())
if H != 0:
    if M < 45:
        print(f'{H - 1} {M + 15}')
    else:
        print(f'{H} {M - 45}')
elif H == 0:
    if M < 45 and 0 <= M <= 59:
        print(f'23 {M + 15}')
    else:
        print(f'{H} {M - 45}')
# Out:
# 10 10
# 9 25
