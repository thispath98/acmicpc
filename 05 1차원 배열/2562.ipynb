# %%
numbers = []
for i in range(9):
    number = int(input())
    numbers.append(number)
max_num = max(numbers)
print(max_num)
print(numbers.index(max_num) + 1)
# Out:
# 3
# 29
# 38
# 12
# 57
# 74
# 40
# 85
# 61
# 85
# 7
