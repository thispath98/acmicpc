# %%
N = int(input())
for i in range(N):
    for k in range(N - i - 1):
        print(' ',end='')
    for s in range(i + 1):
        print('*',end='')
    print('')
# Out:
# 5
#     *
#    **
#   ***
#  ****
# *****
